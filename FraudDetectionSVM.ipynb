# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
cc=pd.read_csv('creditcard.csv')
cc.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
# 5  0.260314 -0.568671  ...   -0.208254 -0.559825 -0.026398 -0.371427
# 6  0.081213  0.464960  ...   -0.167716 -0.270710 -0.154104 -0.780055
# 7 -3.807864  0.615375  ...    1.943465 -1.015455  0.057504 -0.649709
# 8  0.851084 -0.392048  ...   -0.073425 -0.268092 -0.204233  1.011592
# 9  0.069539 -0.736727  ...   -0.246914 -0.633753 -0.120794 -0.385050
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
# 5 -0.232794  0.105915  0.253844  0.081080    3.67      0
# 6  0.750137 -0.257237  0.034507  0.005168    4.99      0
# 7 -0.415267 -0.051634 -1.206921 -1.085339   40.80      0
# 8  0.373205 -0.384157  0.011747  0.142404   93.20      0
# 9 -0.069733  0.094199  0.246219  0.083076    3.68      0
#
# [10 rows x 31 columns]

# %%
fraudCount = cc[cc['Class'] == 1] 
plt.figure(figsize=(15,10))
plt.scatter(fraudCount['Time'], fraudCount['Amount']) 
plt.xlabel('Time')
plt.ylabel('Amount')
plt.show()

# %%
FraudNum=len(cc[cc.Class==1])
print(FraudNum)
UnFraudNum=len(cc[cc.Class==0])
print(UnFraudNum)
# Out:
# 492
# 284315

# %%
fraudData=cc[cc.Class==1]
equalsizeUnFraud=cc[cc.Class==0]
equalsizeUnFraud=equalsizeUnFraud.sample(500)

# %%
fraudData.head(5)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...         V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...    0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...    0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ...   -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...    0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ...   -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# 541   0.320198  0.044519  0.177840  0.261145 -0.143276    0.00      1
# 623  -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00      1
# 4920 -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93      1
# 6108 -0.053502  0.252405 -0.657488 -0.827136  0.849573   59.00      1
# 6329 -1.632653  1.488901  0.566797 -0.010016  0.146793    1.00      1
#
# [5 rows x 31 columns]

# %%
equalsizeUnFraud.count()
# Out:
# Time      500
# V1        500
# V2        500
# V3        500
# V4        500
# V5        500
# V6        500
# V7        500
# V8        500
# V9        500
# V10       500
# V11       500
# V12       500
# V13       500
# V14       500
# V15       500
# V16       500
# V17       500
# V18       500
# V19       500
# V20       500
# V21       500
# V22       500
# V23       500
# V24       500
# V25       500
# V26       500
# V27       500
# V28       500
# Amount    500
# Class     500
# dtype: int64

# %%
equalsizeUnFraud.head(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 75238    55964.0 -0.650222 -0.846749  1.995079 -0.843374 -1.695087  1.394913
# 182291  125336.0 -0.205927  0.941441 -1.928990 -0.288898  4.188524  3.152463
# 45041    42181.0 -0.568526 -0.255217  1.318110  0.167526 -0.672717  0.044793
# 130593   79387.0  1.225606 -0.549656  0.753306 -0.899120 -1.166719 -0.359011
# 273642  165639.0  2.031408 -0.364297 -0.726244 -0.022185 -0.174491  0.086654
#
#               V7        V8        V9  ...         V21       V22       V23  \
# 75238  -0.021813  0.418508 -1.293293  ...    0.226448  0.792373  0.652414
# 182291  0.967508  0.491512 -0.622850  ...    0.041632  0.348719 -0.323117
# 45041   0.501692  0.081600 -1.769316  ...   -0.370443 -1.046275  0.560981
# 130593 -0.815195  0.245952  1.880237  ...   -0.004692  0.106227 -0.065198
# 273642 -0.602889  0.139853  1.217030  ...   -0.143891 -0.328835  0.213922
#
#              V24       V25       V26       V27       V28  Amount  Class
# 75238  -0.262406 -1.044397  1.140526  0.102899  0.172692  262.40      0
# 182291  0.589860 -0.166101 -0.550915 -0.033669 -0.001989    1.00      0
# 45041  -0.131417 -0.701574 -0.698101  0.139148  0.183037  178.05      0
# 130593 -0.026308  0.447711 -0.677141  0.076618  0.017591    1.00      0
# 273642 -1.171432 -0.270393 -0.874850  0.050851 -0.049152    1.00      0
#
# [5 rows x 31 columns]

# %%
new=equalsizeUnFraud.append(fraudData)
new=new.sample(frac=1)
new.head(5)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 226814  144808.0 -2.405207  2.943823 -7.616654  3.533374 -5.417494 -0.112632
# 141257   84204.0 -0.937843  3.462889 -6.445104  4.932199 -2.233983 -2.291561
# 30473    35942.0 -4.194074  4.382897 -5.118363  4.455230 -4.812621 -1.224645
# 24255    33144.0 -1.059535  1.293358  1.388547  0.344437 -0.789471 -0.812129
# 119984   75665.0  1.384410 -0.160164 -0.749916 -0.686859  0.066518 -0.685320
#
#               V7        V8        V9  ...         V21       V22       V23  \
# 226814 -1.329372  1.709417 -2.322716  ...    0.652683  0.414132  0.023869
# 141257 -5.695594  1.338825 -4.322377  ...    1.066550 -0.521657 -0.319917
# 30473  -7.281328  3.332250 -3.679659  ...    1.550473  0.614573  0.028521
# 24255   0.311274  0.279491 -0.025140  ...    0.094855  0.431575 -0.061527
# 119984  0.009282 -0.314600 -1.326616  ...    0.210255  0.616077 -0.280349
#
#              V24       V25       V26       V27       V28  Amount  Class
# 226814 -0.260616  0.405316  0.029107  0.519807 -0.469537  667.55      1
# 141257 -0.405859  0.906802  1.165784  1.374495  0.729889    0.00      1
# 30473   0.013704 -0.149512 -0.131687  0.473934  0.473757   14.46      1
# 24255   0.989865 -0.182826  0.304886 -0.024336  0.137034   19.00      0
# 119984 -0.441023  0.853708  0.016048  0.006784  0.021917   39.00      0
#
# [5 rows x 31 columns]

# %%
X=new.drop(['Class'],axis=1)
X=np.asarray(X)
X[0:5]
# Out:
# array([[ 1.44808000e+05, -2.40520709e+00,  2.94382339e+00,
#         -7.61665422e+00,  3.53337387e+00, -5.41749363e+00,
#         -1.12631915e-01, -1.32937156e+00,  1.70941681e+00,
#         -2.32271561e+00, -6.54098852e+00,  4.40457848e+00,
#         -4.93815929e+00, -7.40984640e-01, -7.46296063e+00,
#          5.34967660e-01, -4.67103153e+00, -4.47240325e+00,
#         -9.82089900e-01,  3.49006859e+00, -3.38706731e-01,
#          6.52683372e-01,  4.14132297e-01,  2.38690731e-02,
#         -2.60616387e-01,  4.05316462e-01,  2.91067416e-02,
#          5.19806552e-01, -4.69537114e-01,  6.67550000e+02],
#        [ 8.42040000e+04, -9.37843305e-01,  3.46288949e+00,
#         -6.44510395e+00,  4.93219867e+00, -2.23398307e+00,
#         -2.29156112e+00, -5.69559393e+00,  1.33882463e+00,
#         -4.32237655e+00, -8.09911940e+00,  7.18296701e+00,
#         -9.44594338e+00, -3.14619968e-01, -1.29914656e+01,
#         -1.36358932e-01, -6.36752438e+00, -1.27343939e+01,
#         -3.84512966e+00,  1.00766726e+00,  1.12953228e+00,
#          1.06655025e+00, -5.21657289e-01, -3.19917293e-01,
#         -4.05859088e-01,  9.06802160e-01,  1.16578389e+00,
#          1.37449533e+00,  7.29889342e-01,  0.00000000e+00],
#        [ 3.59420000e+04, -4.19407368e+00,  4.38289736e+00,
#         -5.11836337e+00,  4.45522984e+00, -4.81262068e+00,
#         -1.22464471e+00, -7.28132787e+00,  3.33224979e+00,
#         -3.67965851e+00, -7.52436834e+00,  2.95434437e+00,
#         -7.09982534e+00,  1.52036891e+00, -7.68780277e+00,
#         -2.25002021e-01, -8.52085017e+00, -1.32772997e+01,
#         -5.25370462e+00,  3.62333181e+00,  5.79098498e-01,
#          1.55047297e+00,  6.14572855e-01,  2.85207918e-02,
#          1.37043245e-02, -1.49512013e-01, -1.31686656e-01,
#          4.73934222e-01,  4.73757482e-01,  1.44600000e+01],
#        [ 3.31440000e+04, -1.05953502e+00,  1.29335794e+00,
#          1.38854652e+00,  3.44437270e-01, -7.89471334e-01,
#         -8.12128786e-01,  3.11274318e-01,  2.79491165e-01,
#         -2.51404031e-02, -4.82105098e-01, -5.08154921e-01,
#          8.57198351e-01,  5.14188073e-01, -1.68922000e-01,
#         -7.96275844e-01, -5.88413776e-01,  4.01645191e-01,
#         -6.19416049e-01,  1.21893545e-01, -5.81676725e-02,
#          9.48547222e-02,  4.31575150e-01, -6.15274003e-02,
#          9.89864934e-01, -1.82825629e-01,  3.04885892e-01,
#         -2.43361934e-02,  1.37034316e-01,  1.90000000e+01],
#        [ 7.56650000e+04,  1.38440986e+00, -1.60163982e-01,
#         -7.49915907e-01, -6.86859444e-01,  6.65175707e-02,
#         -6.85320103e-01,  9.28232572e-03, -3.14599654e-01,
#         -1.32661624e+00,  1.97778963e-01,  1.90164314e-02,
#         -1.10617336e-01,  1.62242658e+00, -1.17001711e+00,
#          6.53979132e-01,  8.45219598e-01,  1.13238904e+00,
#         -1.56297601e+00,  2.88840331e-01,  2.25450023e-01,
#          2.10255454e-01,  6.16076817e-01, -2.80349251e-01,
#         -4.41023291e-01,  8.53707745e-01,  1.60477949e-02,
#          6.78407658e-03,  2.19169889e-02,  3.90000000e+01]])

# %%
from sklearn import preprocessing
X=preprocessing.StandardScaler().fit(X).transform(X)

# %%
y=new['Class']
y=np.asarray(y)
y[0:5]
# Out:
# array([1, 1, 1, 0, 0])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.3, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (694, 30) (694,)
# Test set: (298, 30) (298,)

# %%
from sklearn import svm
model=svm.SVC(kernel='linear',probability=True)
model.fit(X_train,y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
yhat=model.predict(X_test)
yhat[0:5]
# Out:
# array([1, 0, 1, 0, 1])

# %%
from sklearn.metrics import confusion_matrix,classification_report
cm=confusion_matrix(y_test,yhat,labels=[1,0])
np.set_printoptions(precision=2)
print(classification_report(y_test,yhat))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.93      0.97      0.95       152
#           1       0.96      0.92      0.94       146
#
# avg / total       0.95      0.95      0.95       298

# %%
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)
# Out:
# 0.9463087248322147

# %%
from sklearn.metrics import log_loss
yhat_prob=model.predict_proba(X_test)
log_loss(y_test,yhat_prob)
# Out:
# 0.1501514804727111
